# %%
from bikipy.utils.ray_tracing_numba.nbspatial import ray_tracing

# %%
ray_tracing(6., 5., np.array([(0., 0.), (1., 0.), (1., 1.), (0., 1.)])
# Out:
# ---------------------------------------------------------------------------
# SystemError                               Traceback (most recent call last)
# <ipython-input-2-8797e9fe5d16> in <module>
# ----> 1 ray_tracing(6., 5., [(0., 0.), (1., 0.), (1., 1.), (0., 1.)])
#
# SystemError: exception RuntimeError<class 'ValueError'> not a BaseException subclass
